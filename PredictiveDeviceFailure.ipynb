# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib as plt

# %%
# %matplotlib inline

# %%
df = pd.read_csv("/home/hari/Downloads/Turbofan Engine/train_FD001.csv")

# %%
df.head(10)
# Out:
#    unitnumber  timeincycles     os1     os2  os3     sm1     sm2      sm3  \
# 0           1             1 -0.0007 -0.0004  100  518.67  641.82  1589.70
# 1           1             2  0.0019 -0.0003  100  518.67  642.15  1591.82
# 2           1             3 -0.0043  0.0003  100  518.67  642.35  1587.99
# 3           1             4  0.0007  0.0000  100  518.67  642.35  1582.79
# 4           1             5 -0.0019 -0.0002  100  518.67  642.37  1582.85
# 5           1             6 -0.0043 -0.0001  100  518.67  642.10  1584.47
# 6           1             7  0.0010  0.0001  100  518.67  642.48  1592.32
# 7           1             8 -0.0034  0.0003  100  518.67  642.56  1582.96
# 8           1             9  0.0008  0.0001  100  518.67  642.12  1590.98
# 9           1            10 -0.0033  0.0001  100  518.67  641.71  1591.24
#
#        sm4    sm5   ...       sm12     sm13     sm14    sm15  sm16  sm17  \
# 0  1400.60  14.62   ...     521.66  2388.02  8138.62  8.4195  0.03   392
# ...

# %%
df.describe()
# Out:
#          unitnumber  timeincycles           os1           os2      os3  \
# count  20631.000000  20631.000000  20631.000000  20631.000000  20631.0
# mean      51.506568    108.807862     -0.000009      0.000002    100.0
# std       29.227633     68.880990      0.002187      0.000293      0.0
# min        1.000000      1.000000     -0.008700     -0.000600    100.0
# 25%       26.000000     52.000000     -0.001500     -0.000200    100.0
# 50%       52.000000    104.000000      0.000000      0.000000    100.0
# 75%       77.000000    156.000000      0.001500      0.000300    100.0
# max      100.000000    362.000000      0.008700      0.000600    100.0
#
#             sm1           sm2           sm3           sm4           sm5  \
# count  20631.00  20631.000000  20631.000000  20631.000000  2.063100e+04
# mean     518.67    642.680934   1590.523119   1408.933782  1.462000e+01
# std        0.00      0.500053      6.131150      9.000605  1.776400e-15
# ...

# %%
df['unitnumber'].value_counts()
# Out:
# 69    362
# 92    341
# 96    336
# 67    313
# 83    293
# 2     287
# 95    283
# 64    283
# 86    278
# 17    276
# 56    275
# 5     269
# 84    267
# 7     259
# 94    258
# 54    257
# 46    256
# 81    240
# 11    240
# 20    234
# 31    234
# 59    231
# 48    231
# 78    231
# 25    230
# 75    229
# 10    222
# 89    217
# 41    216
# 49    215
#      ...
# 35    181
# 62    180
# 14    180
# 3     179
# 87    178
# 63    174
# 60    172
# 37    170
# 12    170
# 23    168
# 74    166
# 28    165
# 29    163
# 13    163
# 19    158
# 45    158
# 36    158
# 98    156
# 27    156
# 93    155
# 90    154
# 77    154
# 65    153
# 8     150
# 58    147
# 24    147
# 57    137
# 70    137
# 91    135
# 39    128
# Name: unitnumber, dtype: int64

# %%
#Distribution Analysis

# %%
df.boxplot(column='os1')

# %%
df['unitnumber'].hist(bins=50)

# %%
df.boxplot(column='unitnumber')

# %%
#categorical Analysis

# %%
temp1 = df['sm13'].value_counts(ascending=True)
temp2 = df.pivot_table(values='sm17',index=['sm13'],aggfunc=lambda x: x.map({'Y':1,'N':0}).mean())
print('Frequency Table for operation settings 3:')
print(temp1)

print('\nProbility of getting sm1 for each os3 class:' )
print(temp2)
# Out:
# Frequency Table for operation settings 3:
# 2387.88       1
# 2388.49       1
# 2388.54       1
# 2387.89       1
# 2388.56       1
# 2387.90       1
# 2388.55       1
# 2388.44       1
# 2388.39       2
# 2387.91       2
# 2388.37       3
# 2388.36       6
# 2388.35       7
# 2388.34       8
# 2387.92      12
# 2387.93      19
# 2388.33      22
# 2388.32      29
# 2388.31      33
# 2388.30      44
# 2387.94      54
# 2388.29      61
# 2388.28      89
# 2387.95      95
# 2388.27     102
# 2388.26     121
# 2388.25     137
# 2388.24     160
# 2387.96     170
# 2387.97     219
# 2388.23     221
# 2388.22     231
# 2388.21     258
# 2388.20     330
# 2387.98     352
# 2388.19     387
# 2387.99     440
# 2388.18     443
# 2388.17     558
# 2388.00     573
# 2388.16     665
# 2388.01     699
# 2388.02     790
# 2388.15     817
# 2388.03     855
# 2388.14     914
# 2388.04     952
# 2388.13     976
# 2388.05     987
# 2388.06    1005
# 2388.12    1099
# 2388.07    1112
# 2388.11    1127
# ...

# %%
#data Cleaning
#checking missing values
df.apply(lambda x: sum(x.isnull()),axis=0)
# Out:
# unitnumber      0
# timeincycles    0
# os1             0
# os2             0
# os3             0
# sm1             0
# sm2             0
# sm3             0
# sm4             0
# sm5             0
# sm6             0
# sm7             0
# sm8             0
# sm9             0
# sm10            0
# sm11            0
# sm12            0
# sm13            0
# sm14            0
# sm15            0
# sm16            0
# sm17            0
# sm18            0
# sm19            0
# sm20            0
# sm21            0
# dtype: int64

# %%
#building predictive model
from sklearn.preprocessing import LabelEncoder
var_mod = ['timeincycles','sm1','sm2','sm3','sm4','sm5','sm6','sm7','sm8','sm9','sm10','sm11','sm12','sm13','sm14','sm15','sm16','sm17']
le = LabelEncoder()
for i in var_mod:
    df[i] = le.fit_transform(df[i])
df.dtypes
# Out:
# unitnumber        int64
# timeincycles      int64
# os1             float64
# os2             float64
# os3               int64
# sm1               int64
# sm2               int64
# sm3               int64
# sm4               int64
# sm5               int64
# sm6               int64
# sm7               int64
# sm8               int64
# sm9               int64
# sm10              int64
# sm11              int64
# sm12              int64
# sm13              int64
# sm14              int64
# sm15              int64
# sm16              int64
# sm17              int64
# sm18              int64
# sm19              int64
# sm20            float64
# sm21            float64
# dtype: object

# %%
#Import models from scikit learn module:
from sklearn.linear_model import LogisticRegression
from sklearn.cross_validation import KFold   #For K-fold cross validation
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn import metrics

#Generic function for making a classification model and accessing performance:
def classification_model(model, data, predictors, outcome):
  #Fit the model:
  model.fit(data[predictors],data[outcome])
  
  #Make predictions on training set:
  predictions = model.predict(data[predictors])
  
  #Print accuracy
  accuracy = metrics.accuracy_score(predictions,data[outcome])
  print("Accuracy : %s" % "{0:.3%}".format(accuracy))

  #Perform k-fold cross-validation with 5 folds
  kf = KFold(data.shape[0], n_folds=5)
  error = []
  for train, test in kf:
    # Filter training data
    train_predictors = (data[predictors].iloc[train,:])
    
    # The target we're using to train the algorithm.
    train_target = data[outcome].iloc[train]
    
    # Training the algorithm using the predictors and target.
    model.fit(train_predictors, train_target)
    
    #Record error from each cross-validation run
    error.append(model.score(data[predictors].iloc[test,:], data[outcome].iloc[test]))
 
  print("Cross-Validation Score : %s" % "{0:.3%}".format(np.mean(error)))

  #Fit the model again so that it can be refered outside the function:
  model.fit(data[predictors],data[outcome])

# %%
#logistic regression
outcome_var = 'unitnumber'
model = LogisticRegression()
predictor_var = ['sm4']
classification_model(model, df,predictor_var,outcome_var)
# Out:
# Accuracy : 2.210%
# Cross-Validation Score : 0.000%

# %%
#decison tree
model = DecisionTreeClassifier()
predictor_var = ['unitnumber','sm13','sm15','sm16']
classification_model(model, df,predictor_var,outcome_var)
# Out:
# Accuracy : 100.000%
# Cross-Validation Score : 4.018%

# %%
#random forest
model = RandomForestClassifier(n_estimators=100)
predictor_var = ['timeincycles','sm1','sm2','sm3','sm4','sm5','sm6','sm7','sm8','sm9','sm10']
classification_model(model, df,predictor_var,outcome_var)
# Out:
# Accuracy : 100.000%
# Cross-Validation Score : 0.015%

# %%
featimp = pd.Series(model.feature_importances_, index=predictor_var).sort_values(ascending=False)
print(featimp)
# Out:
# sm9             0.181201
# timeincycles    0.166743
# sm4             0.141977
# sm7             0.137427
# sm3             0.137248
# sm2             0.132848
# sm8             0.098714
# sm6             0.003841
# sm10            0.000000
# sm5             0.000000
# sm1             0.000000
# dtype: float64

# %%
model = RandomForestClassifier(n_estimators=25, min_samples_split=25, max_depth=7, max_features=1)
predictor_var = ['sm9','timeincycles','sm4','sm7','sm3']
classification_model(model, df,predictor_var,outcome_var)
# Out:
# Accuracy : 18.443%
# Cross-Validation Score : 0.000%
